# %% [markdown]
# # intrduction to Notebooks
# This is just introduction about Databricks Notebooks

# %%
print('hello..')
print('bye..')

# %%
print('hello again....')
#test

# %%
# %sql
select 'Subbu'
