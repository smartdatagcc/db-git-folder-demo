-- %% [markdown]
-- ### Extract Data from the Orders JSON File
--  1. Query Orders File Using JSON Format
--  2. Query Orders File using TEXT Format
--  3. Create Orders View in Bronze Schema

-- %% [markdown]
-- ### 1. Query Orders File using JSON Format

-- %%
select * from json.`/Volumes/gizmobox_sivan/landing/operational_data_volume/orders`;

-- %% [markdown]
-- ### 2. Query Orders File using TEXT Format

-- %%
select * from text.`/Volumes/gizmobox_sivan/landing/operational_data_volume/orders`;

-- %% [markdown]
-- ### 3. Craeted Orders view in Bronze `schema`

-- %%
CREATE OR REPLACE VIEW gizmobox_sivan.bronze.v_orders
AS
select * from text.`/Volumes/gizmobox_sivan/landing/operational_data_volume/orders`;

-- %%
select * from gizmobox_sivan.bronze.v_orders;
