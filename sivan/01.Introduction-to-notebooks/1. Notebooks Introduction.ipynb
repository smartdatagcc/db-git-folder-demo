# %% [markdown]
# # Introudction to Notebooks
# # Heading 1
# ## Heading 2
# ### Heading 3
#
# - bullet 1
# - bullte 2
#
# This notebooks gives you an introduction to databricks notebooks!

# %%
print('hello')

print('world')

# %%
print('hello again')

# %%
# %sql

select 'Hello from SQL!'
