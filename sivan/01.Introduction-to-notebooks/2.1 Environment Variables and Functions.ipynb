# %%
env = 'dev'

# %%
import os
import platform

def print_env_info():
    # Print Python version
    print(f"Python version: {platform.python_version()}")
    # Print Spark version
    print(f"Spark version: {spark.version}")
    # Print Databricks Runtime version
    runtimeversion = os.environ['DATABRICKS_RUNTIME_VERSION']
    print(f"Running on: {runtimeversion}")
